# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [raw]
# exercise 4

# %%
from sklearn.datasets import make_moons
from matplotlib.colors import ListedColormap

cm_bright = ListedColormap(['#FF0000','#0000FF'])

X, y = make_moons(noise=0.3, random_state=0)

# %% [raw]
# Apparently, the following dataset cannot be separated linearly, i.e., by a straight line.

# %%
cm_bright = ListedColormap(['#FF0000','#0000FF'])
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cm_bright)

# %% [raw]
# SVC is support vector classifier. Three kernels are used in this exercise
# i) Linear
# ii) Polynomial
# iii) Radical
#
# SVC with non-linear kernel is SVM. The second and the third are SVM.

# %%
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score

linear = SVC(kernel='linear')
poly = SVC(kernel='poly', degree=7) # degree greater than one is requested in the question
radical = SVC(kernel='rbf')

lin_score = cross_val_score(linear, X, y, cv=5).mean()
poly_score = cross_val_score(poly, X, y, cv=5).mean()
rad_score = cross_val_score(radical, X, y, cv=5).mean()

print("Linear:\t{}".format(lin_score))
print("Poly:\t{}".format(poly_score))
print("Radical:\t{}".format(rad_score))
# Out:
# Linear:	0.8300000000000001
# Poly:	0.69
# Radical:	0.8699999999999999
# /home/mak/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/mak/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/mak/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/mak/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/mak/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/mak/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/mak/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/mak/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/mak/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/mak/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %% [raw]
# exercise 5

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import uniform

# %%
x1 = uniform.rvs(size=500) - 0.5
x2 = uniform.rvs(size=500) - 0.5
X = np.stack((x1, x2), axis=1)
y = 1 * ((x1 ** 2 - x2 ** 2) > 0)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
from sklearn.linear_model import LogisticRegression

reg = LogisticRegression().fit(X, y)
# Out:
# /home/mak/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
pred = reg.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=pred)
