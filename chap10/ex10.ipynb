# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA

# %% [raw]
# a)

# %%
X, y = make_blobs(n_samples=60, n_features=50, centers=3, cluster_std=15, random_state=1)

plt.scatter(X[:,0], X[:,1], c=y)

# %% [raw]
# b)

# %%
pca = PCA(n_components=2)
pca.fit(X)

X_reduced = pca.transform(X)
plt.scatter(X_reduced[:,0], X_reduced[:,1], c=y)

# %% [raw]
# c)

# %%
y_pred = KMeans(n_clusters=3).fit_predict(X)
confusion_matrix(y, y_pred)
# Out:
# array([[17,  3,  0],
#        [ 0, 20,  0],
#        [ 0,  8, 12]])

# %% [raw]
# d)

# %%
y_pred = KMeans(n_clusters=2).fit_predict(X)
confusion_matrix(y, y_pred)
# Out:
# array([[18,  2,  0],
#        [17,  3,  0],
#        [ 3, 17,  0]])

# %% [raw]
# e)

# %%
y_pred = KMeans(n_clusters=4).fit_predict(X)
confusion_matrix(y, y_pred)
# Out:
# array([[12,  0,  8,  0],
#        [ 7,  0,  4,  9],
#        [ 3,  6, 11,  0],
#        [ 0,  0,  0,  0]])

# %% [raw]
# f)

# %%
y_pred = KMeans(n_clusters=3).fit_predict(X_reduced)
confusion_matrix(y, y_pred)
# Out:
# array([[ 0,  0, 20],
#        [ 0, 19,  1],
#        [18,  1,  1]])

# %% [raw]
# g) After scaling, the prediction isn't improved much.

# %%
X = pd.DataFrame(X)
summary = X.describe()
mean = summary.loc['mean']
std = summary.loc['std']

X_scaled = (X - mean) / std

y_pred = KMeans(n_clusters=3).fit_predict(X_scaled)
confusion_matrix(y, y_pred)
# Out:
# array([[ 0, 20,  0],
#        [ 0,  6, 14],
#        [17,  1,  2]])
